# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

incident_data = pd.read_csv('FireIncidents.csv') #read in dataset

incident_data = incident_data.dropna() #remove anything with no data

print(incident_data.head(10)) #data preview

neighborhoods = ["Mount Washington", "East Hills", "Fairywood", "Central Business District", "East Liberty", "Brighton Heights", "Shadyside", "Hazelwood", "South Side Flats", "Squirrel Hill South", "Squirrel Hill North"] #holds the neighborhoods

incident_count = {neighborhood: 0 for neighborhood in neighborhoods}
for index, row in incident_data.iterrows():
    neighborhood = row['neighborhood']
    if neighborhood in neighborhoods:
        incident_count[neighborhood] += 1
        
print()
print("Amount of fire incidents in each neighborhood:")
print(incident_count)

plt.bar(incident_count.keys(), incident_count.values())
plt.xlabel('Neighborhood')
plt.ylabel('Number of Fire Incidents')
plt.title('Amount of Fire Incidents per Neighborhood')
plt.show()
# Out:
#     _id     call_no  incident_type                      type_description  \
# 3     4  F170043431          131.0                Passenger vehicle fire
# 4     5  F180021111          111.0                         Building fire
# 5     6  F180021782          150.0           Outside rubbish fire, Other
# 6     7  F180022495          113.0   Cooking fire, confined to container
# 7     8  F180022546          111.0                         Building fire
# 8     9  F180022773          111.0                         Building fire
# 9    10  F170044316          131.0                Passenger vehicle fire
# 10   11  F130085568          151.0  Outside rubbish, trash or waste fire
# 11   12  F150016873          118.0      Trash or rubbish fire, contained
# 13   14  F180022999          111.0                         Building fire
#
#                                            address  alarms  \
# 3       1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212       0
# ...

# %% [markdown]
# The best neighborhood would be the one with the least amount of fire incidents. Therefore, Fairywood would be the safest and thus best neighborhood to live in.

# %% [markdown]
# I chose this dataset because I felt as though it was something that could make a neighborhood much safer. The amount of fires a neighborhood has can really determine how safe it is to  live in the area.

# %% [markdown]
# ![Fire Count per Pittsburgh Neighborhood.png](attachment:4e6a8052-8e59-4cea-8e06-1170133f60d4.png)
